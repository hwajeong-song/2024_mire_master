# %% [markdown]
# <a href="https://colab.research.google.com/github/hwajeong-song/2024_mire_master/blob/main/%EA%B3%BC%EC%A0%9C01_%ED%83%90%EC%83%89%EC%A0%81%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_%EC%86%A1%ED%99%94%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 탐색적데이터분석
#
# ## 공공 데이터 분석 - 제주도 서귀포시 제과점 위치 분석

# %% [markdown]
# ---

# %% [markdown]
# **[주의!] (코랩)한글 폰트 지정하는 방법**

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 코랩에서 위 코드를 실행시킨 후  반드시 코랩 메뉴: "런타임>런타임 다시 시작" 합니다.
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# ### #제주도 서귀포시 제과점 위치 데이터 분석하는 순서
#  [사전준비] 필요한 파이썬 라이브러리 설치하기 <br>
#  [사전준비] 데이터 준비하기 : 웹 사이트에서 공공데이터 다운로드하기
#  1. 데이터 불러오기 : 파이썬으로 데이터 읽어서 표로 나타내기
#  2. 데이터 전처리하기 : 필요한 데이터만 추출하기
#  3. 데이터 시각화하기 : 데이터 그래프로 나타내기
#  4. 데이터 저장하기 :  파일로 저장하기

# %% [markdown]
# # 필요한 라이브러리 import

# %%
import matplotlib.pyplot as plt
import numpy as np

# 멧플롯립 한글폰트 지정
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ---

# %% [markdown]
# ### 1.데이터 다운로드하기

# %% [markdown]
# - 공공데이터 포털에서 제주특별자치도 서귀포시 제과점 현황 데이터를 다운로드한다.
# - https://data.go.kr
# - csv파일 다운로드해서 사용

# %% [markdown]
# ---------

# %% [markdown]
# ### 2. 데이터 불러오기 : 파이썬으로 데이터 읽어서 표로 나타내기

# %%
import pandas as pd

file = '제주특별자치도_서귀포시_제과점현황_20240401.csv'
df = pd.read_csv(file, encoding='cp949')

print(type(df))
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      업종명                          업소명                            소재지(도로명)  \
# 0  제과점영업           노베케이션(No Vacation)          제주특별자치도 서귀포시 표선면 민속해안로 635
# 1  제과점영업            그랜드파파(Grand papa)  제주특별자치도 서귀포시 태평로353번길 14, 1층 (서귀동)
# 2  제과점영업               위드윗(withwheat)          제주특별자치도 서귀포시 중앙로 261 (서홍동)
# 3  제과점영업                         허니제과        제주특별자치도 서귀포시 대정읍 서광남로 77, 1층
# 4  제과점영업  도트베이글팩토리(DOT BAGEL FACTORY)     제주특별자치도 서귀포시 서호호근로96번길 20 (서호동)
#
#                        소재지(지번)         위도          경도     데이터기준일자
# 0   제주특별자치도 서귀포시 표선면 표선리 40-3   33.325364  126.837714  2024-04-01
# 1      제주특별자치도 서귀포시 서귀동 829-5   33.246848  126.560673  2024-04-01
# 2      제주특별자치도 서귀포시 서홍동 166-5   33.267520  126.558177  2024-04-01
# 3  제주특별자치도 서귀포시 대정읍 구억리 365-5   33.280342  126.301778  2024-04-01
# 4      제주특별자치도 서귀포시 서호동 325-1   33.255598  126.526362  2024-04-01

# %% [markdown]
# ---

# %% [markdown]
# ### 2.데이터 전처리(가공하기)
# - 함수 참고:  https://pandas.pydata.org/docs/reference/index.html

# %% [markdown]
# #### # 데이터 요약

# %%
# 데이터 요약 정보
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   업종명       167 non-null    object
#  1   업소명       167 non-null    object
#  2   소재지(도로명)  165 non-null    object
#  3   소재지(지번)   167 non-null    object
#  4   위도        167 non-null    float64
#  5   경도        167 non-null    float64
#  6   데이터기준일자   167 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 9.3+ KB

# %% [markdown]
# #결측치 데이터 확인하기

# %%
#행에 결측 데이터 시각화
import missingno as msno
import matplotlib.pyplot as plt

# 코랩에서 한글 폰트 설치한 후 사용하기!!!
# plt.rc('font', family='cmb10')                  # (코랩)한글 폰트
plt.rc('font', family='NanumBarunGothic')       # (코랩)한글 폰트
# plt.rc('font', family='Malgun Gothic')          # (win)한글 폰트

msno.matrix(df)
plt.show()

# %% [markdown]
# @결측치 확인

# %%
df[ df.isnull() ]

# 결측치가 포함된 컬럼의 모든 행 가져오기
df[df.isnull().any(axis=1)]  # axis=1 (컬럼 기준)
# Out:
#        업종명     업소명 소재지(도로명)                      소재지(지번)         위도  \
# 144  제과점영업    빵하우스      NaN      제주특별자치도 서귀포시 동홍동 645-3   33.252836
# 159  제과점영업  빙그레제과점      NaN  제주특별자치도 서귀포시 대정읍 하모리 824번지   33.221995
#
#              경도     데이터기준일자
# 144  126.570179  2024-04-01
# 159  126.254367  2024-04-01

# %% [markdown]
# #불필요한 컬럼 삭제하기

# %%
df.drop(columns=['업종명', '소재지(도로명)', '데이터기준일자'], inplace=True)
df.head()
# Out:
#                            업소명                      소재지(지번)         위도  \
# 0           노베케이션(No Vacation)   제주특별자치도 서귀포시 표선면 표선리 40-3   33.325364
# 1            그랜드파파(Grand papa)      제주특별자치도 서귀포시 서귀동 829-5   33.246848
# 2               위드윗(withwheat)      제주특별자치도 서귀포시 서홍동 166-5   33.267520
# 3                         허니제과  제주특별자치도 서귀포시 대정읍 구억리 365-5   33.280342
# 4  도트베이글팩토리(DOT BAGEL FACTORY)      제주특별자치도 서귀포시 서호동 325-1   33.255598
#
#            경도
# 0  126.837714
# 1  126.560673
# 2  126.558177
# 3  126.301778
# 4  126.526362

# %% [markdown]
# #소재지(지번) 주소에서 읍면동 정보 추출하고 자리를 잡아주기

# %%
df['읍면동'] = df['소재지(지번)'].str.split(' ').str[2]
df = df[['업소명', '소재지(지번)', '읍면동', '위도', '경도']]
df.head()
# Out:
#                            업소명                      소재지(지번)  읍면동         위도  \
# 0           노베케이션(No Vacation)   제주특별자치도 서귀포시 표선면 표선리 40-3   표선면  33.325364
# 1            그랜드파파(Grand papa)      제주특별자치도 서귀포시 서귀동 829-5   서귀동  33.246848
# 2               위드윗(withwheat)      제주특별자치도 서귀포시 서홍동 166-5   서홍동  33.267520
# 3                         허니제과  제주특별자치도 서귀포시 대정읍 구억리 365-5   대정읍  33.280342
# 4  도트베이글팩토리(DOT BAGEL FACTORY)      제주특별자치도 서귀포시 서호동 325-1   서호동  33.255598
#
#            경도
# 0  126.837714
# 1  126.560673
# 2  126.558177
# 3  126.301778
# 4  126.526362

# %% [markdown]
# #그룹핑(컬럼1개):읍면동 별 제과점의 현황

# %%
store_count = df['업소명'].groupby(df['읍면동']).count()
store_count
# Out:
# 읍면동
# 강정동     6
# 남원읍    10
# 대정읍    26
# 동홍동    13
# 법환동     6
# 상예동     1
# 색달동     5
# 서귀동    12
# 서호동     8
# 서홍동     6
# 성산읍    16
# 신효동     1
# 안덕면    23
# 월평동     1
# 중문동     9
# 토평동     2
# 표선면    10
# 하효동     9
# 호근동     1
# 회수동     2
# Name: 업소명, dtype: int64

# %% [markdown]
# # 데이터 탐색하기
# - 질문1.빵집이 제일 많은 동네는 어디일까?

# %%
df['읍면동'].value_counts()
# Out:
# 읍면동
# 대정읍    26
# 안덕면    23
# 성산읍    16
# 동홍동    13
# 서귀동    12
# 남원읍    10
# 표선면    10
# 하효동     9
# 중문동     9
# 서호동     8
# 법환동     6
# 서홍동     6
# 강정동     6
# 색달동     5
# 회수동     2
# 토평동     2
# 상예동     1
# 신효동     1
# 월평동     1
# 호근동     1
# Name: count, dtype: int64

# %%
top1 = df.loc[df['읍면동']=='대정읍'][['업소명', '소재지(지번)']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 3 to 165
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   업소명      26 non-null     object
#  1   소재지(지번)  26 non-null     object
# dtypes: object(2)
# memory usage: 624.0+ bytes

# %% [markdown]
# # 중문동에 있는 빵집의 이름 알아보기

# %%
df.loc[df['읍면동']=='중문동'][['소재지(지번)', '업소명']]
# Out:
#                            소재지(지번)             업소명
# 27        제주특별자치도 서귀포시 중문동 1588-1           돌카롱중문점
# 71      제주특별자치도 서귀포시 중문동 2184-4번지       해성정육마트베이커리
# 75   제주특별자치도 서귀포시 중문동 2082번지 , 1층            더건강한빵
# 110       제주특별자치도 서귀포시 중문동 1489-1           해성베이커리
# 114       제주특별자치도 서귀포시 중문동 1733-5             듀브레드
# 120    제주특별자치도 서귀포시 중문동 2028-1 1층         뚜레쥬르 중문점
# 135         제주특별자치도 서귀포시 중문동 2700   제주국제컨벤선센터 베이커리
# 141         제주특별자치도 서귀포시 중문동 1928        중문하나로베이커리
# 154       제주특별자치도 서귀포시 중문동 2120-1        파리바게뜨 중문점

# %% [markdown]
# #데이터 시각화 하기
# - 지도위에 위치와 정보 표시하기

# %%
#folium사용하기
import folium

map = folium.Map(location = [33.3616666,126.5291666 ], zoom_start= 10)
tooltip = 'click'
folium.Marker(
    location = [33.3616666,126.5291666 ],
    popup = '<strong>hello jeju</strong>',
    icon = folium.Icon(color = 'pink', icon = 'heart'),
    tooltip = tooltip
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91e0dd81684687fcfcd5e039be31be5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91e0dd81684687fcfcd5e039be31be5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91e0dd81684687fcfcd5e039be31be5f = L.map(
#                 &quot;map_91e0dd81684687fcfcd5e039be31be5f&quot;,
#                 {
#                     center: [33.3616666, 126.5291666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea13f2758fcfcfb7d1ab456a1c254125 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ea13f2758fcfcfb7d1ab456a1c254125.addTo(map_91e0dd81684687fcfcd5e039be31be5f);
#
#
#             var marker_d0bf2205eb59812eac1fe8ef92d05e60 = L.marker(
#                 [33.3616666, 126.5291666],
#                 {}
#             ).addTo(map_91e0dd81684687fcfcd5e039be31be5f);
#
#
#             var icon_61235ab35fb715661bfa9937c211d5c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0bf2205eb59812eac1fe8ef92d05e60.setIcon(icon_61235ab35fb715661bfa9937c211d5c2);
#
#
#         var popup_e831987e32c97e86197aaaa692702cb6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6476d169db2f439139167cfe26ac2f83 = $(`&lt;div id=&quot;html_6476d169db2f439139167cfe26ac2f83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello jeju&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_e831987e32c97e86197aaaa692702cb6.setContent(html_6476d169db2f439139167cfe26ac2f83);
#
#
#
#         marker_d0bf2205eb59812eac1fe8ef92d05e60.bindPopup(popup_e831987e32c97e86197aaaa692702cb6)
#         ;
#
#
#
#
#             marker_d0bf2205eb59812eac1fe8ef92d05e60.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#제과점 위치 마커 표시하기
for idx in df.index :
  lat = df.loc[idx,'위도']
  lng = df.loc[idx,'경도']
  marker = folium.Marker(
      location = [lat, lng],
      popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
      {df.loc[idx, '소재지(지번)']}</div>",
      icon = folium.Icon(color='orange', icon='cloud')
      )
  marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91e0dd81684687fcfcd5e039be31be5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91e0dd81684687fcfcd5e039be31be5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91e0dd81684687fcfcd5e039be31be5f = L.map(
#                 &quot;map_91e0dd81684687fcfcd5e039be31be5f&quot;,
#                 {
#                     center: [33.3616666, 126.5291666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea13f2758fcfcfb7d1ab456a1c254125 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ea13f2758fcfcfb7d1ab456a1c254125.addTo(map_91e0dd81684687fcfcd5e039be31be5f);
#
#
#             var marker_d0bf2205eb59812eac1fe8ef92d05e60 = L.marker(
#                 [33.3616666, 126.5291666],
#                 {}
#             ).addTo(map_91e0dd81684687fcfcd5e039be31be5f);
#
#
#             var icon_61235ab35fb715661bfa9937c211d5c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0bf2205eb59812eac1fe8ef92d05e60.setIcon(icon_61235ab35fb715661bfa9937c211d5c2);
#
#
#         var popup_e831987e32c97e86197aaaa692702cb6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6476d169db2f439139167cfe26ac2f83 = $(`&lt;div id=&quot;html_6476d169db2f439139167cfe26ac2f83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello jeju&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_e831987e32c97e86197aaaa692702cb6.setContent(html_6476d169db2f439139167cfe26ac2f83);
#
#
#
#         marker_d0bf2205eb59812eac1fe8ef92d05e60.bindPopup(popup_e831987e32c97e86197aaaa692702cb6)
#         ;
#
#
#
#
#             marker_d0bf2205eb59812eac1fe8ef92d05e60.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_ea13f2758fcfcfb7d1ab456a1c254125.addTo(map_91e0dd81684687fcfcd5e039be31be5f);
#
#
#             var marker_ea1309017d3a2673b2daa0f38447f69b = L.marker(
#                 [33.32536384, 126.8377136],
#                 {}
#             ).addTo(map_91e0dd81684687fcfcd5e039be31be5f);
#
#
#             var icon_7242a989daa5e12f02c07a1a3d38086a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea1309017d3a2673b2daa0f38447f69b.setIcon(icon_7242a989daa5e12f02c07a1a3d38086a);
#
#
#         var popup_2a09489be3b5b56278d9f4a8f74c1b32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44db1a6553f486b202e59a96851d126f = $(`&lt;div id=&quot;html_44db1a6553f486b202e59a96851d126f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;노베케이션(No Vacation)&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 표선면 표선리 40-3 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_2a09489be3b5b56278d9f4a8f74c1b32.setContent(html_44db1a6553f486b202e59a96851d126f);
#
#
#
#         marker_ea1309017d3a2673b2daa0f38447f69b.bindPopup(popup_2a09489be3b5b56278d9f4a8f74c1b32)
#         ;
#
#
#
#
#             var marker_a6fb1d129acc0fe4d2d103d1c657fbd5 = L.marker(
#                 [33.24684824, 126.5606733],
#                 {}
#             ).addTo(map_91e0dd81684687fcfcd5e039be31be5f);
#
#
#             var icon_9f369f8f1a01c62651aaa582259b4d09 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a6fb1d129acc0fe4d2d103d1c657fbd5.setIcon(icon_9f369f8f1a01c62651aaa582259b4d09);
#
#
#         var popup_db7c0a8cd27abcb046e8f14a92bae736 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6290fa424367a44bb1a9d10678bf3f2 = $(`&lt;div id=&quot;html_b6290fa424367a44bb1a9d10678bf3f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;그랜드파파(Grand papa)&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 서귀동 829-5 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_db7c0a8cd27abcb046e8f14a92bae736.setConte

# %%
# 마커에 업소명과 소재지 정보 넣기
from folium.plugins import MarkerCluster

map = folium.Map(location = [33.3616666,126.5291666 ],
                 zoom_start= 10
                 )

marker_cluster = MarkerCluster().add_to(map)

for idx in df.index :
  lat = df.loc[idx,'위도']
  lng = df.loc[idx,'경도']
  marker = folium.Marker(
      location = [lat, lng],
      popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
      {df.loc[idx, '소재지(지번)']}</div>",
      icon = folium.Icon(color='orange', icon='cloud')
      )
  marker.add_to(marker_cluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df6f5a1918bc30e303366e55f0ae8e5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df6f5a1918bc30e303366e55f0ae8e5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df6f5a1918bc30e303366e55f0ae8e5b = L.map(
#                 &quot;map_df6f5a1918bc30e303366e55f0ae8e5b&quot;,
#                 {
#                     center: [33.3616666, 126.5291666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf01e5b12c700d4df99d121f7ddef71e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bf01e5b12c700d4df99d121f7ddef71e.addTo(map_df6f5a1918bc30e303366e55f0ae8e5b);
#
#
#             var marker_cluster_de8e2563e841312dfb5b1bd0bbac79f5 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_73bd5cfb474a7d1cbd4e90ba1e4a11af = L.marker(
#                 [33.32536384, 126.8377136],
#                 {}
#             ).addTo(marker_cluster_de8e2563e841312dfb5b1bd0bbac79f5);
#
#
#             var icon_0e47cd16e61e92ace973bcdbea24a665 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_73bd5cfb474a7d1cbd4e90ba1e4a11af.setIcon(icon_0e47cd16e61e92ace973bcdbea24a665);
#
#
#         var popup_1d2fd78f1ece6c65114a5ec8ab5b0679 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_585ab5c716091c5a6aa4ff0bd025ce66 = $(`&lt;div id=&quot;html_585ab5c716091c5a6aa4ff0bd025ce66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;노베케이션(No Vacation)&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 표선면 표선리 40-3 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_1d2fd78f1ece6c65114a5ec8ab5b0679.setContent(html_585ab5c716091c5a6aa4ff0bd025ce66);
#
#
#
#         marker_73bd5cfb474a7d1cbd4e90ba1e4a11af.bindPopup(popup_1d2fd78f1ece6c65114a5ec8ab5b0679)
#         ;
#
#
#
#
#             var marker_09ffd7522f8acd28537b0e761a7a7a32 = L.marker(
#                 [33.24684824, 126.5606733],
#                 {}
#             ).addTo(marker_cluster_de8e2563e841312dfb5b1bd0bbac79f5);
#
#
#             var icon_3e8648c908bdd98f7943e04d5dfaf159 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_09ffd7522f8acd28537b0e761a7a7a32.setIcon(icon_3e8648c908bdd98f7943e04d5dfaf159);
#
#
#         var popup_948ae3935095812736cc4193c9858a23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_773a66f548c251833bbf35a6fe567506 = $(`&lt;div id=&quot;html_773a66f548c251833bbf35a6fe567506&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;width:100px&#x27;&gt; &lt;strong&gt;그랜드파파(Grand papa)&lt;/strong&gt;&lt;br&gt;      제주특별자치도 서귀포시 서귀동 829-5 &lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_948ae3935095812736cc4193c9858a23.setContent(html_773a66f548c251833bbf35a6fe567506);
#
#
#
#         marker_09ffd7522f8acd28537b0e761a7a7a32.bindPopup(popup_948ae3935095812736cc4193c9858a23)
#         ;
#
#
#
#
#             var marker_afdcd13bfa7ee069840bf85f2e8b3b87 = L.marker(
#                 [33.26752037, 126.5581773],
#                 {}
#             ).addTo(marker_cluster_de8e2563e841312dfb5b1bd0bbac79f5);
#
#
#             var icon_8a726264716395743e456892d34f0e4f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_afdcd13bfa7ee069840bf85f2e8b3b87.setIcon(icon_8a726264716395743e456892d34f0e4f);
#
#
#         var popup_ad6cd3a21a420e5bdad1c3122e138c16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var h

# %% [markdown]
# #### # 기술통계 정보

# %%
df.describe('읍면동')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-85323a7de1a7> in <cell line: 1>()
# ----> 1 df.describe('읍면동')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   11550         max            NaN      3.0
#   11551         """
# > 11552         return describe_ndframe(
#   11553             obj=self,
#   11554             include=include,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/methods/describe.py in describe_ndframe(obj, include, exclude, percentiles)
#      81     Dataframe or series description.
#      82     """
# ---> 83     percentiles = _refine_percentiles(percentiles)
#      84
#      85     describer: NDFrameDescriberAbstract
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/methods/describe.py in _refine_percentiles(percentiles)
#     398
#     399     # get them all to be in [0, 1]
# --> 400     validate_percentile(percentiles)
#     401
#     402     # median should always be included
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_validators.py in validate_percentile(q)
#     337             raise ValueError(msg)
#     338     else:
# --> 339         if not all(0 <= qs <= 1 for qs in q_arr):
#     340             raise ValueError(msg)
#     341     return q_arr
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_validators.py in <genexpr>(.0)
#     337             raise ValueError(msg)
#     338     else:
# --> 339         if not all(0 <= qs <= 1 for qs in q_arr):
#     340             raise ValueError(msg)
#     341     return q_arr
#
# TypeError: '<=' not supported between instances of 'int' and 'numpy.str_'

# %% [markdown]
# #### # 결측데이터 시각화
# missingno패키지는 pandas 데이터프레임 데이터에서 누락된 데이터를 찾고 시각화하는 기능 제공

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in /usr/local/lib/python3.10/dist-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from missingno) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn->missingno) (2.1.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->missingno) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %% [markdown]
# - **행에 결측 데이터 시각화**

# %%
import missingno as msno
import matplotlib.pyplot as plt

# 코랩에서 한글 폰트 설치한 후 사용하기!!!
# plt.rc('font', family='cmb10')                  # (코랩)한글 폰트
plt.rc('font', family='NanumBarunGothic')       # (코랩)한글 폰트
# plt.rc('font', family='Malgun Gothic')          # (win)한글 폰트

msno.matrix(df)
plt.show()

# %% [markdown]
# - **열에 결측 데이터 시각화**

# %%
msno.bar(df)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### 2. 컬럼명 변경하기

# %%
df.columns
df.columns = ['지점', '지점명', '일시', '평균기온', '최고기온', '최저기온', '평균현지기압',
       '평균상대습도', '월합강수량', '평균풍속','일조시간', '최심적설']
df.head(3)
# Out:
#    지점 지점명       일시  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  평균풍속   일조시간  최심적설
# 0  90  속초  1968-01  -0.7  11.4 -11.4  1018.2    47.0    0.0   2.1  218.6   NaN
# 1  90  속초  1968-02  -2.1   9.7  -9.9  1022.8    51.0    3.3   2.2  236.5   1.8
# 2  90  속초  1968-03   5.9  20.5  -3.2  1016.1    57.0    8.8   2.1  223.7   0.0

# %%
# 특정 컬럼명 변경
df = df.rename(columns={'평균기온(°C)':'평균기온', '최고기온(°C)':'최고기온'})

# %% [markdown]
# ### @결측치 확인

# %%
df[ df.isnull() ]

# 결측치가 포함된 컬럼의 모든 행 가져오기
df[df.isnull().any(axis=1)]  # axis=1 (컬럼 기준)
# Out:
#         지점  지점명       일시  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  평균풍속  \
# 0       90   속초  1968-01  -0.7  11.4 -11.4  1018.2    47.0    0.0   2.1
# 3       90   속초  1968-04  10.5  21.4   4.0  1019.4    63.0    6.9   2.0
# 4       90   속초  1968-05  14.6  24.5   9.3  1011.7    74.0   49.1   2.2
# 5       90   속초  1968-06  18.5  29.2  11.4  1009.1    82.0   48.3   1.9
# 6       90   속초  1968-07  22.8  35.8  17.1  1005.7    87.0  304.7   1.6
# ...    ...  ...      ...   ...   ...   ...     ...     ...    ...   ...
# 57700  296  북부산  2024-06  23.2  33.6  13.0  1008.5    74.0  177.0   1.9
# 57701  296  북부산  2024-07  27.1  37.0  21.2  1008.4    87.0  217.0   2.5
# 57702  296  북부산  2024-08  29.3  36.8  22.6  1007.4    80.0   73.5   2.3
# 57703  296  북부산  2024-09  26.5  36.2  17.0  1013.2    77.0  418.5   2.4
# 57704  296  북부산  2024-10   NaN  29.7  12.1     NaN     NaN   17.5   NaN
#
#         일조시간  최심적설
# 0      218.6   NaN
# 3      255.7   NaN
# 4      187.8   NaN
# 5      182.2   NaN
# 6      117.4   NaN
# ...      ...   ...
# 57700  183.3   NaN
# 57701  144.7   NaN
# 57702  239.6   NaN
# 57703  169.8   NaN
# 57704   52.2   NaN
#
# [45956 rows x 12 columns]

# %%
# 평균기온이 null인 행들 가져오기
df[ df['평균기온'].isnull() ]

# '평균기온'이 null이고 '일시'가 '2024-10'가 아닌 행들 가져오기
df_data = df[ (df['평균기온'].isnull()) & (df['일시'] != '2024-10') ]
df_data.head(2)
# Out:
#        지점  지점명       일시  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  평균풍속  일조시간  \
# 1817  100  대관령  1971-07   NaN  25.6  19.6     NaN     NaN    NaN   NaN   NaN
# 1818  100  대관령  1971-08   NaN  29.6   6.7     NaN     NaN  200.8   2.3   NaN
#
#       최심적설
# 1817   NaN
# 1818   NaN

# %% [markdown]
# #### 3. 컬럼 추가하기
# DataFrame.insert(추가하고싶은위치,컬럼명,값, allow_duplicate=False)

# %%
df.insert(3,'신규',df['지점'])
df.head(2)
# Out:
#    지점 지점명       일시  신규  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  평균풍속   일조시간  \
# 0  90  속초  1968-01  90  -0.7  11.4 -11.4  1018.2    47.0    0.0   2.1  218.6
# 1  90  속초  1968-02  90  -2.1   9.7  -9.9  1022.8    51.0    3.3   2.2  236.5
#
#    최심적설
# 0   NaN
# 1   1.8

# %%
df.insert(3,'검색일자',df['일시'])

# %%
df.head(3)
# Out:
#    지점 지점명       일시     검색일자  신규  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 0  90  속초  1968-01  1968-01  90  -0.7  11.4 -11.4  1018.2    47.0    0.0
# 1  90  속초  1968-02  1968-02  90  -2.1   9.7  -9.9  1022.8    51.0    3.3
# 2  90  속초  1968-03  1968-03  90   5.9  20.5  -3.2  1016.1    57.0    8.8
#
#    평균풍속   일조시간  최심적설
# 0   2.1  218.6   NaN
# 1   2.2  236.5   1.8
# 2   2.1  223.7   0.0

# %% [markdown]
# - **문자열에서 특정 문자 제거**: '검색일자' 값중에 '년도-월-일' 형태로 되어 있는 구조에서  '-'기호를 제거

# %%
df['검색일자']= df['검색일자'].str.replace(pat=r'-',repl=r'',regex=True)
df.head(2)
# Out:
#    지점 지점명       일시    검색일자  신규  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  평균풍속  \
# 0  90  속초  1968-01  196801  90  -0.7  11.4 -11.4  1018.2    47.0    0.0   2.1
# 1  90  속초  1968-02  196802  90  -2.1   9.7  -9.9  1022.8    51.0    3.3   2.2
#
#     일조시간  최심적설
# 0  218.6   NaN
# 1  236.5   1.8

# %% [markdown]
# - **데이터형 변환하기**: str(object)-->int64 형으로 변환하기

# %%
df['검색일자'].dtypes   # 컬럼의 데이터형 조회
# Out:
# dtype('O')

# %%
df['검색일자'] = df['검색일자'].apply('int64')  # 정수형으로 변경하기
df.dtypes
# Out:
# 지점          int64
# 지점명        object
# 일시         object
# 검색일자        int64
# 신규          int64
# 평균기온      float64
# 최고기온      float64
# 최저기온      float64
# 평균현지기압    float64
# 평균상대습도    float64
# 월합강수량     float64
# 평균풍속      float64
# 일조시간      float64
# 최심적설      float64
# dtype: object

# %% [markdown]
# - **데이터형 변환하기**: int64 --> str(object)형으로 변환하기

# %%
df['검색일자'] = df['검색일자'].apply(str)
df.dtypes
# Out:
# 지점          int64
# 지점명        object
# 일시         object
# 검색일자       object
# 신규          int64
# 평균기온      float64
# 최고기온      float64
# 최저기온      float64
# 평균현지기압    float64
# 평균상대습도    float64
# 월합강수량     float64
# 평균풍속      float64
# 일조시간      float64
# 최심적설      float64
# dtype: object

# %%
# 년월 컬럼 추가
df.insert(3,'년도',df['일시'].str[0:4])
df.head(2)
# Out:
#    지점 지점명       일시    년도    검색일자  신규  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 0  90  속초  1968-01  1968  196801  90  -0.7  11.4 -11.4  1018.2    47.0    0.0
# 1  90  속초  1968-02  1968  196802  90  -2.1   9.7  -9.9  1022.8    51.0    3.3
#
#    평균풍속   일조시간  최심적설
# 0   2.1  218.6   NaN
# 1   2.2  236.5   1.8

# %%
# 월 컬럼 추가
df.insert(4,'월',df['일시'].str[5:7])
df.head(2)
# Out:
#    지점 지점명       일시    년도   월    검색일자  신규  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  \
# 0  90  속초  1968-01  1968  01  196801  90  -0.7  11.4 -11.4  1018.2    47.0
# 1  90  속초  1968-02  1968  02  196802  90  -2.1   9.7  -9.9  1022.8    51.0
#
#    월합강수량  평균풍속   일조시간  최심적설
# 0    0.0   2.1  218.6   NaN
# 1    3.3   2.2  236.5   1.8

# %% [markdown]
# #### 4. 컬럼 삭제

# %%
# 컬럼 삭제 (drop(컬럼이름, axis=1, inplace=True)
df.drop('신규', axis=1, inplace=True)
df.drop('검색일자', axis=1, inplace=True)
df.head(3)
# Out:
#    지점 지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  평균풍속  \
# 0  90  속초  1968-01  1968  01  -0.7  11.4 -11.4  1018.2    47.0    0.0   2.1
# 1  90  속초  1968-02  1968  02  -2.1   9.7  -9.9  1022.8    51.0    3.3   2.2
# 2  90  속초  1968-03  1968  03   5.9  20.5  -3.2  1016.1    57.0    8.8   2.1
#
#     일조시간  최심적설
# 0  218.6   NaN
# 1  236.5   1.8
# 2  223.7   0.0

# %% [markdown]
# #### 5. 특정 조건 검색

# %%
print( '#지점명 개수: ', len( set(df['지점명']) ) )  # 고유한(unique)값만 뽑기 위해 set() 자료형에 대입
print( '#지점명: ', set( df['지점명'] ) )
# Out:
# #지점명 개수:  104
# #지점명:  {'서청주', '흑산도', '대관령', '태백', '금산', '성산포', '영덕', '해남', '의성', '고창', '강릉', '장흥', '삼척', '울산', '경주시', '완도', '여수', '세종', '추풍령', '영월', '창원', '양산시', '동해', '인제', '대구', '구미', '보은', '북강릉', '북부산', '부산', '백령도', '북춘천', '거제', '영천', '남해', '군산', '정선군', '전주', '관악산', '천안', '대전', '북창원', '정읍', '제천', '포항', '함양군', '청송군', '무안', '순창군', '김해시', '울진', '순천', '상주', '수원', '영광군', '강진군', '산청', '청주', '홍성', '목포', '대구(기)', '춘천', '철원', '합천', '양평', '서귀포', '서울', '서산', '광주', '임실', '진도(첨찰산)', '진주', '원주', '울릉도', '고흥', '성산', '동두천', '보성군', '문경', '의령군', '인천', '고산', '부여', '고창군', '보령', '파주', '광양시', '충주', '진도군', '봉화', '밀양', '홍천', '영주', '강화', '안동', '통영', '남원', '거창', '이천', '장수', '제주', '주암', '부안', '속초'}

# %%
# 2024년도의 데이타만 추출
df_2024 = df.query(" 년도 == '2024' ")
df_2024 = df[ df['년도'] == '2024' ]
df_2024
# Out:
#         지점  지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 672     90   속초  2024-01  2024  01   0.6  11.1 -12.3  1021.2    53.0   11.6
# 673     90   속초  2024-02  2024  02   1.9  18.1  -5.6  1023.1    75.0  125.7
# 674     90   속초  2024-03  2024  03   5.7  20.6  -7.4  1015.2    58.0   58.6
# 675     90   속초  2024-04  2024  04  13.9  27.1   2.1  1012.1    66.0   63.4
# 676     90   속초  2024-05  2024  05  17.8  33.2   6.5  1009.7    61.0   63.4
# ...    ...  ...      ...   ...  ..   ...   ...   ...     ...     ...    ...
# 57700  296  북부산  2024-06  2024  06  23.2  33.6  13.0  1008.5    74.0  177.0
# 57701  296  북부산  2024-07  2024  07  27.1  37.0  21.2  1008.4    87.0  217.0
# 57702  296  북부산  2024-08  2024  08  29.3  36.8  22.6  1007.4    80.0   73.5
# 57703  296  북부산  2024-09  2024  09  26.5  36.2  17.0  1013.2    77.0  418.5
# 57704  296  북부산  2024-10  2024  10   NaN  29.7  12.1     NaN     NaN   17.5
#
#        평균풍속   일조시간  최심적설
# 672     2.0  203.4   NaN
# 673     1.7  109.7   NaN
# 674     2.2  212.9   NaN
# 675     2.2  195.2   NaN
# 676     2.6  253.2   NaN
# ...     ...    ...   ...
# 57700   1.9  183.3   NaN
# 57701   2.5  144.7   NaN
# 57702   2.3  239.6   NaN
# 57703   2.4  169.8   NaN
# 57704   NaN   52.2   NaN
#
# [970 rows x 14 columns]

# %%
# 2024년도의 지점명 개수와 목록
print( '#지점명 개수: ', len( set(df_2024['지점명']) ) )
print( '#지점명: ', set( df_2024['지점명'] ) )
# Out:
# #지점명 개수:  97
# #지점명:  {'서청주', '흑산도', '대관령', '태백', '금산', '영덕', '해남', '의성', '고창', '강릉', '장흥', '울산', '경주시', '완도', '여수', '세종', '추풍령', '영월', '창원', '양산시', '동해', '인제', '대구', '구미', '보은', '북강릉', '북부산', '부산', '백령도', '북춘천', '거제', '영천', '남해', '군산', '정선군', '전주', '천안', '대전', '북창원', '정읍', '제천', '포항', '함양군', '청송군', '순창군', '김해시', '울진', '순천', '상주', '수원', '영광군', '강진군', '산청', '청주', '홍성', '목포', '춘천', '철원', '합천', '양평', '서귀포', '서울', '서산', '광주', '임실', '진주', '원주', '울릉도', '고흥', '성산', '동두천', '보성군', '문경', '의령군', '인천', '고산', '부여', '고창군', '보령', '파주', '광양시', '충주', '진도군', '봉화', '밀양', '홍천', '영주', '강화', '안동', '통영', '남원', '거창', '이천', '장수', '제주', '부안', '속초'}

# %% [markdown]
# ### [퀴즈] 1904년도(최초 측정) 지점명 개수와 목록

# %%
# 1904년도 최초 측정일 때 지점명 개수와 목록
df_1904 = df[ df['년도'] == '1904' ]
print( '#지점명 개수: ', len( set(df_1904['지점명']) ) )
print( '#지점명: ', set( df_1904['지점명'] ) )
# Out:
# #지점명 개수:  3
# #지점명:  {'목포', '인천', '부산'}

# %%
df_1904
# Out:
#         지점 지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 6777   112  인천  1904-04  1904  04   NaN  19.2   6.4     NaN     NaN  104.9
# 6778   112  인천  1904-05  1904  05  14.3  23.8   8.8     NaN     NaN   50.5
# 6779   112  인천  1904-06  1904  06  19.7  30.3  12.6     NaN     NaN   34.6
# 6780   112  인천  1904-07  1904  07  23.5  32.8  17.0     NaN     NaN  293.7
# 6781   112  인천  1904-08  1904  08  25.5  33.3  17.5     NaN     NaN  117.4
# 6782   112  인천  1904-09  1904  09  20.9  30.1  11.1     NaN     NaN   17.1
# 6783   112  인천  1904-10  1904  10  13.7  27.5   1.3     NaN     NaN   25.6
# 6784   112  인천  1904-11  1904  11   5.9  16.6  -4.1     NaN     NaN   16.9
# 6785   112  인천  1904-12  1904  12   0.4  13.3  -9.6     NaN     NaN   11.5
# 22879  159  부산  1904-04  1904  04   NaN  21.4   4.7     NaN     NaN  172.9
# 22880  159  부산  1904-05  1904  05  15.7  23.6   8.7     NaN    71.0  231.8
# 22881  159  부산  1904-06  1904  06  20.7  29.8  13.8     NaN    79.0  120.0
# 22882  159  부산  1904-07  1904  07  23.7  31.9  16.8     NaN    85.0  490.8
# 22883  159  부산  1904-08  1904  08  25.5  32.0  17.1     NaN    76.0   48.7
# 22884  159  부산  1904-09  1904  09  21.6  30.4  12.9     NaN    74.0   73.9
# 22885  159  부산  1904-10  1904  10  16.2  25.7   4.2     NaN    64.0   36.2
# 22886  159  부산  1904-11  1904  11   9.5  21.3  -0.4     NaN    53.0    2.8
# 22887  159  부산  1904-12  1904  12   5.4  19.6  -5.1     NaN    52.0   12.2
# 25100  165  목포  1904-04  1904  04   NaN  20.2   NaN     NaN     NaN   34.7
# 25101  165  목포  1904-05  1904  05   NaN  21.3   NaN     NaN     NaN    NaN
# 25102  165  목포  1904-06  1904  06   NaN  28.0   NaN     NaN     NaN   89.2
# 25103  165  목포  1904-07  1904  07   NaN  29.5   NaN     NaN     NaN   24.8
# 25104  165  목포  1904-08  1904  08   NaN  30.3   NaN     NaN     NaN   67.5
# 25105  165  목포  1904-09  1904  09   NaN   NaN   NaN     NaN     NaN   55.3
# 25106  165  목포  1904-10  1904  10   NaN  25.1   NaN     NaN     NaN   23.0
# 25107  165  목포  1904-11  1904  11   NaN  20.3   NaN     NaN     NaN   14.1
# 25108  165  목포  1904-12  1904  12   NaN  17.1   NaN     NaN     NaN    NaN
#
#        평균풍속  일조시간  최심적설
# 6777    NaN   NaN   NaN
# 6778    NaN   NaN   NaN
# 6779    NaN   NaN   NaN
# 6780    NaN   NaN   NaN
# 6781    NaN   NaN   NaN
# 6782    NaN   NaN   NaN
# 6783    NaN   NaN   NaN
# 6784    NaN   NaN   NaN
# 6785    NaN   NaN   NaN
# 22879   NaN   NaN   NaN
# 22880   4.2   NaN   NaN
# 22881   3.7   NaN   NaN
# 22882   5.5   NaN   NaN
# 22883   6.2   NaN   NaN
# 22884   4.5   NaN   NaN
# 22885   4.8   NaN   NaN
# 22886   6.9   NaN   NaN
# 22887   8.5   NaN   NaN
# 25100   NaN   NaN   NaN
# 25101   NaN   NaN   NaN
# 25102   NaN   NaN   NaN
# 25103   NaN   NaN   NaN
# 25104   NaN   NaN   NaN
# 25105   NaN   NaN   NaN
# 25106   NaN   NaN   NaN
# 25107   NaN   NaN   NaN
# 25108   NaN   NaN   NaN

# %% [markdown]
# - **특정 컬럼명 검색** : 지점명=='제주' 데이터

# %%
# df[df.지점명 == '제주' ]

df.query(" 지점명 == '제주' ")

# df.iloc[ df.index[ df['지점명'] == '제주' ] ]
# Out:
#         지점 지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 29200  184  제주  1923-05  1923  05  16.5  27.0   8.3     NaN    82.0   70.7
# 29201  184  제주  1923-06  1923  06  19.7  31.2  10.4     NaN    82.0  385.3
# 29202  184  제주  1923-07  1923  07  23.6  33.0  17.1     NaN    86.0  359.5
# 29203  184  제주  1923-08  1923  08  26.7  34.6  20.2     NaN    77.0   92.2
# 29204  184  제주  1923-09  1923  09  22.1  30.4  13.4     NaN    78.0  145.0
# ...    ...  ..      ...   ...  ..   ...   ...   ...     ...     ...    ...
# 30413  184  제주  2024-06  2024  06  23.1  31.4  16.8  1005.9    73.0  271.8
# 30414  184  제주  2024-07  2024  07  28.9  35.5  22.6  1004.9    73.0  156.0
# 30415  184  제주  2024-08  2024  08  29.9  35.0  25.2  1004.2    72.0   47.0
# 30416  184  제주  2024-09  2024  09  27.6  35.1  21.1  1009.1    73.0  126.2
# 30417  184  제주  2024-10  2024  10   NaN  28.3  16.9     NaN     NaN   51.1
#
#        평균풍속   일조시간  최심적설
# 29200   5.2  200.4   NaN
# 29201   5.1  227.3   NaN
# 29202   5.9  218.8   NaN
# 29203   6.6  301.7   NaN
# 29204   7.0  224.4   NaN
# ...     ...    ...   ...
# 30413   2.8  155.0   NaN
# 30414   3.5  204.9   NaN
# 30415   2.9  275.2   NaN
# 30416   2.9  131.5   NaN
# 30417   NaN   35.1   NaN
#
# [1218 rows x 14 columns]

# %% [markdown]
# - **또는(|) , 포함(in)** 조건 사용: 제주 또는 서귀포 데이터 추출

# %%
# 또는(|) 사용
df.query(" 지점명=='제주' | 지점명=='서귀포' ")
df.head()

df.query(" 지점명=='제주' | 지점명=='서귀포' ").head()
df_jeju = df.query(" 지점명 in ('제주','서귀포','성산','성산포','고산') ")
df_jeju
# Out:
#         지점  지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 29200  184   제주  1923-05  1923  05  16.5  27.0   8.3     NaN    82.0   70.7
# 29201  184   제주  1923-06  1923  06  19.7  31.2  10.4     NaN    82.0  385.3
# 29202  184   제주  1923-07  1923  07  23.6  33.0  17.1     NaN    86.0  359.5
# 29203  184   제주  1923-08  1923  08  26.7  34.6  20.2     NaN    77.0   92.2
# 29204  184   제주  1923-09  1923  09  22.1  30.4  13.4     NaN    78.0  145.0
# ...    ...  ...      ...   ...  ..   ...   ...   ...     ...     ...    ...
# 49070  265  성산포  2006-11  2006  11  14.3  24.1   4.9  1016.6    68.0   85.5
# 49071  265  성산포  2006-12  2006  12   8.5  17.3   0.2  1023.0    69.0   90.5
# 49072  265  성산포  2007-01  2007  01   6.9  14.6   0.6  1023.0    66.0   46.3
# 49073  265  성산포  2007-02  2007  02   9.1  17.7   0.5  1018.0    67.0   60.7
# 49074  265  성산포  2007-03  2007  03  10.8  19.8   1.2  1016.2    67.0  105.9
#
#        평균풍속   일조시간  최심적설
# 29200   5.2  200.4   NaN
# 29201   5.1  227.3   NaN
# 29202   5.9  218.8   NaN
# 29203   6.6  301.7   NaN
# 29204   7.0  224.4   NaN
# ...     ...    ...   ...
# 49070   3.8  141.5   NaN
# 49071   3.0  115.1   0.3
# 49072   3.3  109.2   1.7
# 49073   3.7  164.2   2.8
# 49074   3.8  137.8   NaN
#
# [3915 rows x 14 columns]

# %% [markdown]
# - **그리고(&)** 조건 사용

# %%
df[ (df.지점명 == '제주' ) & (df.최고기온 >30) ]

df.query(" 지점명=='제주' & 최저기온 <= 0 ")

df_jeju.query("최저기온 <= -3  & 년도 >= '2000' ")
# Out:
#         지점  지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 30132  184   제주  2001-01  2001  01   5.6  15.1  -3.1  1019.6    64.0  117.0
# 30168  184   제주  2004-01  2004  01   5.5  13.6  -3.2  1021.4    63.0   40.6
# 30312  184   제주  2016-01  2016  01   6.1  16.8  -5.8  1022.3    66.0  125.6
# 30372  184   제주  2021-01  2021  01   6.8  18.2  -3.1  1021.9    65.0  116.6
# 30396  184   제주  2023-01  2023  01   6.8  20.7  -3.4  1022.5    68.0   42.1
# 30610  185   고산  2004-01  2004  01   5.0  13.0  -4.5  1014.4    63.0   16.4
# 30670  185   고산  2009-01  2009  01   6.0  14.0  -3.6  1015.3    61.0   22.0
# 30694  185   고산  2011-01  2011  01   2.4   8.4  -3.6  1016.8    61.0    6.5
# 30754  185   고산  2016-01  2016  01   5.6  16.1  -6.2  1015.2    70.0   70.1
# 30838  185   고산  2023-01  2023  01   6.8  17.8  -4.5  1015.2    67.0   56.1
# 31200  187   성산  2001-01  2001  01   4.9  16.6  -4.8  1020.3    76.0  165.0
# 31201  187   성산  2001-02  2001  02   5.4  17.6  -5.1  1021.2    67.0   88.0
# 31211  187   성산  2001-12  2001  12   4.6  15.5  -3.7  1024.8    62.0  166.0
# 31236  187   성산  2004-01  2004  01   4.5  13.1  -4.8  1021.0    66.0   68.5
# 31249  187   성산  2005-02  2005  02   4.6  13.3  -3.4  1020.2    69.0  110.0
# 31259  187   성산  2005-12  2005  12   4.5  18.5  -3.0  1021.9    70.0  112.5
# 31261  187   성산  2006-02  2006  02   5.7  17.3  -3.2  1022.5    67.0   73.5
# 31635  188   성산  2001-01  2001  01   4.9  16.6  -4.8  1020.3    76.0  165.0
# 31636  188   성산  2001-02  2001  02   5.4  17.6  -5.1  1021.2    67.0   88.0
# 31646  188   성산  2001-12  2001  12   4.6  15.5  -3.7  1024.8    62.0  166.0
# 31671  188   성산  2004-01  2004  01   4.5  13.1  -4.8  1021.0    66.0   68.5
# 31684  188   성산  2005-02  2005  02   4.6  13.3  -3.4  1020.2    69.0  110.0
# 31694  188   성산  2005-12  2005  12   4.5  18.5  -3.0  1021.9    70.0  112.5
# 31696  188   성산  2006-02  2006  02   5.7  17.3  -3.2  1022.5    67.0   73.5
# 31731  188   성산  2009-01  2009  01   5.3  15.5  -3.8  1022.0    65.0   67.9
# 31743  188   성산  2010-01  2010  01   4.5  15.9  -4.0  1021.2    68.0   49.4
# 31745  188   성산  2010-03  2010  03   8.5  18.8  -3.2  1017.4    69.0  259.3
# 31755  188   성산  2011-01  2011  01   2.4   9.1  -3.2  1023.7    69.0   19.0
# 31756  188   성산  2011-02  2011  02   7.4  18.6  -3.8  1018.4    69.0  140.2
# 31768  188   성산  2012-02  2012  02   4.9  13.2  -3.6  1020.0    67.0  104.9
# 31780  188   성산  2013-02  2013  02   5.9  16.9  -3.5  1021.0    74.0   97.5
# 31815  188   성산  2016-01  2016  01   5.0  17.5  -6.9  1021.7    71.0  167.8
# 31828  188   성산  2017-02  2017  02   6.0  17.3  -3.8  1020.8    63.0   86.9
# 31839  188   성산  2018-01  2018  01   4.0  15.7  -3.7  1021.1    68.0  102.4
# 31840  188   성산  2018-02  2018  02   4.7  15.7  -3.8  1020.7    62.0  125.7
# 31875  188   성산  2021-01  2021  01   5.9  17.8  -4.6  1021.6    65.0   93.7
# 31899  188   성산  2023-01  2023  01   5.8  18.5  -5.4  1021.8    69.0   69.4
# 32401  189  서귀포  2001-01  2001  01   7.1  16.7  -3.0  1014.8    62.0  150.7
# 32437  189  서귀포  2004-01  2004  01   7.2  15.5  -3.3  1016.6    56.0   15.6
# 32497  189  서귀포  2009-01  2009  01   6.7  14.5  -3.9  1017.6    63.0   50.9
# 32521  189  서귀포  2011-01  2011  01   4.0  10.7  -3.7  1018.7    62.0    5.2
# 32581  189  서귀포  2016-01  2016  01   6.2  16.7  -6.4  1017.1    66.0   74.9
# 32605  189  서귀포  2018-01  2018  01   5.9  16.2  -3.0  1016.1    69.0   63.7
# 32641  189  서귀포  2021-01  2021  01   7.2  17.1  -3.4  1017.1    70.0   54.6
# 32665  189  서귀포  2023-01  2023  01   7.4  17.8  -4.5  1017.5    67.0   71.2
# 49000  265  성산포  2001-01  2001  01   4.9  16.6  -4.8  1020.3    76.0  165.0
# 49001  265  성산포  2001-02  2001  02   5.4  17.6  -5.1  1021.2    67.0   88.0
# 49011  265  성산포  2001-12  2001  12   4.6  15.5  -3.7  1024.8    62.0  166.0
# 49036  265  성산포  2004-01  2004  01   4.5  13.1  -4.8  1021.0    66.0   68.5
# 49049  265  성산포  2005-02  2005  02   4.6  13.3  -3.4  1020.2    69.0  110.0
# 49059  265  성산포  2005-12  2005  12   4.5  18.5  -3.0  1021.9    70.0  112.5
# 49061  265  성산포  2006-02  2006  02   5.7  17.3  -3.2  1022.5    67.0   73.5
#
#        평균풍속   일조시간  최심적설
# 30132   4.1   62.6  11.8
# 30168   3.5   80.3   5.0
# 30312   4.3   31.4  12.0
# 30372   3.9   96.5   9.2
# 30396   4.0   86.7   3.7
# 30610   7.5   94.3   6.0
# 30670  10.4   68.5   1.4
# 30694  12.2   60.5   1.3
# 30754   9.3   65.3   NaN
# 30838   8.2  109.9   NaN
# 31200   3.8  105.7  23.6
# 31201   3.5  124.5   NaN
# 31211   3.6   96.6   NaN
# 31236   2.9  155.5  12.2
# 31249   4.2  128.6   2.4
# 31259   3.0  136.1   9.6
# 31261   4.1  139.7   0.1
# 31635   3.8  105.7  23.6
# 31636   3.5  124.5   NaN
# 31646   3.6   96.6   NaN
# 31671   2.9  155.5  12.2
# 31684   4.2  128.6   2.4
# 31694   3.0  136.1   9.6
# 31696   4.1  139.7   0.1
# 31731   3.5   94.5  12.9
# 31743   3.5  117.5  14.3
# 31745   4.2  120.1   1.7
# 31755   3.5  110.6  16.4
# 31756   3.3  142.4   5.2
# 31768   2.9   89.9   6.2
# 31780   3.4  149.3   0.8
# 31815   3.1   99.3   NaN
# 31828   3.8  177.6   NaN
# 31839   3.0  133.9   NaN
# 31840   3.2  140.6   NaN
# 31875   2.8  149.2   NaN
# 31899   3.1  142.2   NaN
# 32401   3.4  137.9   3.2
# 32437   2.9  180.9   3.7
# 32497   2.6  114.2   5.1
# 32521   2.3  167.7   9.9
# 32581   1.6  115.2   NaN
# 32605   1.6  163.4   NaN
# 32641   1.8  162.5   4.0
# 32665   1.5  165.9   3.5
# 49000   3.8  105.7  23.6
# 49001   3.5  124.5   NaN
# 49011   3.6   96.6   NaN
# 49036   2.9  155.5  12.2
# 49049   4.2  128.6   2.4
# 49059   3.0  136.1   9.6
# 49061   4.1  139.7   0.1

# %% [markdown]
# ### [실습문제] 기상관측 데이터에서 특징 데이터 찾기
# - 기상관측 지점이 제주인 데이터
# - 가장 더웠던 년도, 월, 기온은?
# - 가장 추웠던 년도, 월, 기온은?

# %%
# 1.기상관측 지점이 제주인 데이터
# 포함(in) 사용
df_jeju = df.query(" 지점명 in ('고산','서귀포','성산','성산포','제주') ")
df_jeju
# Out:
#         지점  지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 29200  184   제주  1923-05  1923  05  16.5  27.0   8.3     NaN    82.0   70.7
# 29201  184   제주  1923-06  1923  06  19.7  31.2  10.4     NaN    82.0  385.3
# 29202  184   제주  1923-07  1923  07  23.6  33.0  17.1     NaN    86.0  359.5
# 29203  184   제주  1923-08  1923  08  26.7  34.6  20.2     NaN    77.0   92.2
# 29204  184   제주  1923-09  1923  09  22.1  30.4  13.4     NaN    78.0  145.0
# ...    ...  ...      ...   ...  ..   ...   ...   ...     ...     ...    ...
# 49070  265  성산포  2006-11  2006  11  14.3  24.1   4.9  1016.6    68.0   85.5
# 49071  265  성산포  2006-12  2006  12   8.5  17.3   0.2  1023.0    69.0   90.5
# 49072  265  성산포  2007-01  2007  01   6.9  14.6   0.6  1023.0    66.0   46.3
# 49073  265  성산포  2007-02  2007  02   9.1  17.7   0.5  1018.0    67.0   60.7
# 49074  265  성산포  2007-03  2007  03  10.8  19.8   1.2  1016.2    67.0  105.9
#
#        평균풍속   일조시간  최심적설
# 29200   5.2  200.4   NaN
# 29201   5.1  227.3   NaN
# 29202   5.9  218.8   NaN
# 29203   6.6  301.7   NaN
# 29204   7.0  224.4   NaN
# ...     ...    ...   ...
# 49070   3.8  141.5   NaN
# 49071   3.0  115.1   0.3
# 49072   3.3  109.2   1.7
# 49073   3.7  164.2   2.8
# 49074   3.8  137.8   NaN
#
# [3915 rows x 14 columns]

# %% [markdown]
# - **min()** : 최초 측정월, 마지막 측정월

# %%
# 측정월 최소, 최대
print ( '최초 측정일시: ', min(df['일시']) )
print ( '최초 측정일시: ', df['일시'].min() )
print ( '최근 측정일시: ', max(df['일시']) )
print ( '최근 측정일시: ', df['일시'].max() )

# 측정 최초월('1904-04')의 데이터
df['일시'].min()
df.query(" 일시 == '1904-04'")

df.query(f" 일시 == '{ df['일시'].min() }' ")

df[ df['일시'] == df['일시'].min() ]
# Out:
# 최초 측정일시:  1904-04
# 최초 측정일시:  1904-04
# 최근 측정일시:  2024-10
# 최근 측정일시:  2024-10
#         지점 지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 6777   112  인천  1904-04  1904  04   NaN  19.2   6.4     NaN     NaN  104.9
# 22879  159  부산  1904-04  1904  04   NaN  21.4   4.7     NaN     NaN  172.9
# 25100  165  목포  1904-04  1904  04   NaN  20.2   NaN     NaN     NaN   34.7
#
#        평균풍속  일조시간  최심적설
# 6777    NaN   NaN   NaN
# 22879   NaN   NaN   NaN
# 25100   NaN   NaN   NaN

# %% [markdown]
# - **max()** : 최근 측정 월 검색

# %%
df['일시'].max()
# Out:
# '2024-10'

# %%
df.query(f" 일시 == '{ df['일시'].max() }' ")
# Out:
#         지점  지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 681     90   속초  2024-10  2024  10   NaN  25.0  11.5     NaN     NaN   33.7
# 778     93  북춘천  2024-10  2024  10   NaN  22.8   6.8     NaN     NaN    0.7
# 1220    95   철원  2024-10  2024  10   NaN  22.8   5.5     NaN     NaN   11.2
# 1542    98  동두천  2024-10  2024  10   NaN  24.5   6.4     NaN     NaN    2.5
# 1816    99   파주  2024-10  2024  10   NaN  23.5   5.8     NaN     NaN    2.7
# ...    ...  ...      ...   ...  ..   ...   ...   ...     ...     ...    ...
# 55788  288   밀양  2024-10  2024  10   NaN  29.2  10.6     NaN     NaN   10.1
# 56418  289   산청  2024-10  2024  10   NaN  26.5  10.5     NaN     NaN   13.5
# 57049  294   거제  2024-10  2024  10   NaN  27.3  13.8     NaN     NaN   16.9
# 57682  295   남해  2024-10  2024  10   NaN  28.1  13.4     NaN     NaN   20.3
# 57704  296  북부산  2024-10  2024  10   NaN  29.7  12.1     NaN     NaN   17.5
#
#        평균풍속  일조시간  최심적설
# 681     NaN  49.4   NaN
# 778     NaN  69.5   NaN
# 1220    NaN  72.5   NaN
# 1542    NaN  69.3   NaN
# 1816    NaN  69.2   NaN
# ...     ...   ...   ...
# 55788   NaN  70.4   NaN
# 56418   NaN  53.8   NaN
# 57049   NaN  57.7   NaN
# 57682   NaN  63.3   NaN
# 57704   NaN  52.2   NaN
#
# [97 rows x 14 columns]

# %%
df.query(f" 지점명 == '제주' & 일시 == '{ df['일시'].max() }' ")

# %%
df.query(f" 지점명 in ('제주','성산','고산','성산포','서귀포') & 일시 == '{ df['일시'].max() }' ")
# Out:
#         지점  지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 30417  184   제주  2024-10  2024  10   NaN  28.3  16.9     NaN     NaN   51.1
# 30859  185   고산  2024-10  2024  10   NaN  27.9  16.1     NaN     NaN   22.4
# 31920  188   성산  2024-10  2024  10   NaN  28.8  16.1     NaN     NaN   51.1
# 32686  189  서귀포  2024-10  2024  10   NaN  30.0  17.1     NaN     NaN   53.3
#
#        평균풍속  일조시간  최심적설
# 30417   NaN  35.1   NaN
# 30859   NaN  54.5   NaN
# 31920   NaN  42.7   NaN
# 32686   NaN  53.8   NaN

# %% [markdown]
# ### [실습]: 가장 더웠던 날짜와 온도는?
# - 기상관측 데이터에서 가장 더웠던(추웠던) 해와 기온은?

# %%
# 컬럼 추출
df['최고기온'].max()
df.최고기온.max()
print(f'최고기온: {df.최고기온.max()}')


# 행 추출
df.query(f" 최고기온 == {  df.최고기온.max()  } ")
df[ df.최고기온 == df.최고기온.max() ]
# Out:
# 최고기온: 41.0
#         지점 지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 36480  212  홍천  2018-08  2018  08  27.2  41.0  15.8   991.7    73.0  300.6
#
#        평균풍속   일조시간  최심적설
# 36480   1.4  234.4   NaN

# %%
df.query(f" 최고기온 == {  df.최고기온.max()  } ")['일시'].str[0:4]
# Out:
# 36480    2018
# Name: 일시, dtype: object

# %%
# 행 추출 특정 컬럼값(year) 추출
print(f'기상관측 데이터를 통해 가장 더웠던 년도는?')
print(df.query(f" 최고기온 == {  df.최고기온.max()  } ").일시.str[0:4] )


yymm = df.query(f" 최고기온 == {  df.최고기온.max()  } ").일시.str[0:7]
yymm = df[ df.최고기온 == df.최고기온.max() ].일시.str[0:7]
print(f'기상관측 데이터를 통해 가장 더웠던 년-월: {yymm}')


# 행 추출 특정 컬럼값(최고기온) 추출
df.query(f" 최고기온 == {  df.최고기온.max()  } ").최고기온
df[ df.최고기온 == df.최고기온.max() ].최고기온
# Out:
# 기상관측 데이터를 통해 가장 더웠던 년도는?
# 36480    2018
# Name: 일시, dtype: object
# 기상관측 데이터를 통해 가장 더웠던 년-월: 36480    2018-08
# Name: 일시, dtype: object
# 36480    41.0
# Name: 최고기온, dtype: float64

# %%
# 전체 최고기온
df.query(f" 최고기온 == {df['최고기온'].max()} ")

# 전체 최고기온 일시
df.query(f" 최고기온 == {df['최고기온'].max()} ")['일시'].str[0:4]

# 전체 최고기온 지점명
df.query(f" 최고기온 == {df['최고기온'].max()} ")['지점명']

# # 측정 지점이 제주인  최고기온
df.query(f" 지점명=='제주' ")['최고기온'].max()


# 측정 지점이 제주 전역의   최고기온
df.query(f" 지점명 in ('고산','서귀포','성산','성산포','제주') ")['최고기온'].max()
# Out:
# 37.5

# %% [markdown]
# ### [실습]: 가장 추웠던 날짜와 온도는?

# %%
field = '최저기온'

# 전체 최저기온
df.query(f" {field} <= { df[field].min() } ")

# 전체 최저기온 일시
df.query(f" {field} <= { df[field].min() } ")['일시'].str[0:4]

# 전체 최저기온 지점명
df.query(f" {field} <= { df[field].min() } ")['지점명']

# 측정 지점이 제주인 최저기온
df.query(f" 지점명=='제주' ")[field].min()

# 측정 지점이 제주 전역의  최고기온
df.query(f" 지점명 in ('고산','서귀포','성산','성산포','제주') ")[field].min()
# Out:
# -7.0

# %% [markdown]
# ###  [실습] : '제주'에서 가장 더웠던 날짜와 기온?

# %%
wmax = df.query(" 지점명 == '제주' ")['최고기온'].max()
print(wmax)
# 해당 레코드
df.query(f" 지점명 == '제주' and 최고기온 >= { wmax }")


wmax = df.query(" 지점명 in ('고산','서귀포','성산','성산포','제주') ")['최고기온'].max()
df.query(f" 지점명 in ('고산','서귀포','성산','성산포','제주') and 최고기온 >= { wmax }")
# Out:
# 37.5
#         지점 지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 29430  184  제주  1942-07  1942  07  27.0  37.5  17.8  1008.8    78.0   15.5
# 30391  184  제주  2022-08  2022  08  29.2  37.5  21.2  1005.8    75.0  124.3
#
#        평균풍속   일조시간  최심적설
# 29430   3.0  347.2   NaN
# 30391   3.1  232.4   NaN

# %%
# 서울에서 가장 더웠던 년도와 기온
wmax = df.query(" 지점명 in ('관악산','서울') ")['최고기온'].max()
df.query(f" 지점명 in ('관악산','서울') and 최고기온 >= { wmax }")

# %% [markdown]
# ###  [실습] : '제주'에서 가장 추웠던 날짜와 기온은?

# %%
wmin = df.query(" 지점명 == '제주' ")['최저기온'].min()
print(wmin)
# 해당 레코드
df.query(f" 지점명 == '제주' and 최저기온 <= { wmin  } ")

wmin = df.query(" 지점명 in ('고산','서귀포','성산','성산포','제주') ")['최저기온'].min()
df.query(f" 지점명 in ('고산','서귀포','성산','성산포','제주') and 최저기온 <= { wmin  } ")
# Out:
# -6.0
#         지점  지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 31068  187   성산  1990-01  1990  01   4.3  17.7  -7.0  1017.4    72.0  118.3
# 31503  188   성산  1990-01  1990  01   4.3  17.7  -7.0  1017.4    72.0  118.3
# 48868  265  성산포  1990-01  1990  01   4.3  17.7  -7.0  1017.4    72.0  118.3
#
#        평균풍속  일조시간  최심적설
# 31068   3.1  99.1   7.6
# 31503   3.1  99.1   7.6
# 48868   3.1  99.1   7.6

# %%
# 서울에서 가장 추웠던 년도와 기온
wmin = df.query(" 지점명 in ('관악산','서울') ")['최저기온'].min()
df.query(f" 지점명 in ('관악산','서울') and 최저기온 <= { wmin  } ")
# Out:
#        지점 지점명       일시    년도   월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 5629  108  서울  1927-12  1927  12  -2.0  10.2 -23.1  1023.0    68.0   43.6
#
#       평균풍속   일조시간  최심적설
# 5629   1.9  150.6  19.5

# %% [markdown]
# --------

# %% [markdown]
# ### 그룹핑(Grouping)

# %% [markdown]
# #### #그룹핑: 지점별

# %%
df.groupby(['지점명'], as_index=False).mean(numeric_only=True)
# df.groupby('지점명').mean(numeric_only=True)
# Out:
#      지점명     지점       평균기온       최고기온      최저기온       평균현지기압     평균상대습도  \
# 0     강릉  105.0  12.626453  25.056867  2.332665  1013.710395  64.027550
# 1    강진군  259.0  14.010169  25.352222  3.705556  1015.050282  72.508475
# 2     강화  201.0  11.202738  22.499842  0.243740  1012.294042  70.565217
# 3     거제  294.0  14.265056  24.429048  4.697302  1012.915137  66.985507
# 4     거창  284.0  11.856361  25.175277 -0.247227   989.833056  70.103060
# ..   ...    ...        ...        ...       ...          ...        ...
# 99    합천  285.0  13.126731  26.142122  1.388264  1012.778065  67.971014
# 100   해남  261.0  13.485346  24.590282  2.647492  1013.509179  74.545894
# 101   홍성  177.0  13.053271  24.728704  1.992593  1013.528037  75.766355
# 102   홍천  212.0  10.640258  24.303651 -1.981905   999.963929  69.661836
# 103  흑산도  169.0  13.690090  22.205090  7.332934  1006.983483  78.879880
#
#           월합강수량      평균풍속        일조시간       최심적설
# 0    112.526468  2.902308  190.101945  17.191809
# 1    122.001667  2.282584  181.926667   7.450000
# 2    108.462986  1.747504  202.176290   4.911034
# 3    156.876575  1.774074  196.257581   3.147727
# 4    105.940670  1.336232  199.818387   5.467901
# ..          ...       ...         ...        ...
# 99   107.506613  1.196452  195.121452   3.942857
# 100  109.546582  2.101935  194.007742   4.406107
# 101  107.275000  1.528037  202.117593   5.039130
# 102  109.944531  0.995484  186.727097   6.472611
# 103   92.614671  5.377778  164.294012   3.711111
#
# [104 rows x 11 columns]

# %%
df.groupby(['지점명'], as_index=False).count()
# Out:
#      지점명    지점    일시    년도     월  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 0     강릉  1347  1347  1347  1347  1342  1347  1347    1164    1343   1345
# 1    강진군   180   180   180   180   177   180   180     177     177    180
# 2     강화   643   643   643   643   621   631   631     621     621    643
# 3     거제   631   631   631   631   621   630   630     621     621    619
# 4     거창   632   632   632   632   621   631   631     602     621    627
# ..   ...   ...   ...   ...   ...   ...   ...   ...     ...     ...    ...
# 99    합천   625   625   625   625   621   622   622     620     621    620
# 100   해남   640   640   640   640   621   638   638     621     621    629
# 101   홍성   108   108   108   108   107   108   108     107     107    108
# 102   홍천   640   640   640   640   621   630   630     621     621    640
# 103  흑산도   334   334   334   334   333   334   334     333     333    334
#
#      평균풍속  일조시간  최심적설
# 0    1343  1337   293
# 1     178   180    14
# 2     621   620   145
# 3     621   620    44
# 4     621   620   162
# ..    ...   ...   ...
# 99    620   620    91
# 100   620   620   131
# 101   107   108    23
# 102   620   620   157
# 103   333   334    72
#
# [104 rows x 14 columns]

# %% [markdown]
# #### #그룹핑(컬럼1개): 지점별  평균기온

# %%
# 방법1
df['평균기온'].groupby(df['지점명']).mean()
# Out:
# 지점명
# 강릉     12.626453
# 강진군    14.010169
# 강화     11.202738
# 거제     14.265056
# 거창     11.856361
#          ...
# 합천     13.126731
# 해남     13.485346
# 홍성     13.053271
# 홍천     10.640258
# 흑산도    13.690090
# Name: 평균기온, Length: 104, dtype: float64

# %%
# 방법2
df.groupby('지점명')['평균기온'].agg('mean')
# Out:
# 지점명
# 강릉     12.626453
# 강진군    14.010169
# 강화     11.202738
# 거제     14.265056
# 거창     11.856361
#          ...
# 합천     13.126731
# 해남     13.485346
# 홍성     13.053271
# 홍천     10.640258
# 흑산도    13.690090
# Name: 평균기온, Length: 104, dtype: float64

# %%
# 방법3
df.groupby('지점명')['평균기온'].agg(**{'평균기온':'mean'})
# Out:
#           평균기온
# 지점명
# 강릉   12.626453
# 강진군  14.010169
# 강화   11.202738
# 거제   14.265056
# 거창   11.856361
# ..         ...
# 합천   13.126731
# 해남   13.485346
# 홍성   13.053271
# 홍천   10.640258
# 흑산도  13.690090
#
# [104 rows x 1 columns]

# %%
# 방법4
df.groupby('지점명').aggregate({'평균기온':'mean'})
# Out:
#           평균기온
# 지점명
# 강릉   12.626453
# 강진군  14.010169
# 강화   11.202738
# 거제   14.265056
# 거창   11.856361
# ..         ...
# 합천   13.126731
# 해남   13.485346
# 홍성   13.053271
# 홍천   10.640258
# 흑산도  13.690090
#
# [104 rows x 1 columns]

# %%
df_temp = df.groupby('지점명').aggregate({'평균기온':'mean'})
df_temp.plot(kind='bar')

df.groupby('지점명').aggregate({'평균기온':'mean'}).plot(kind='bar')
# Out:
# <Axes: xlabel='지점명'>

# %% [markdown]
# #### #그룹핑(컬럼 2개): 지점명+년도별,  평균기온

# %%
df.groupby(['지점명','년도'])['평균기온'].agg('mean')
df.groupby(['지점명','년도'])['평균기온'].agg(**{'평균':'mean'})
df.groupby(['지점명','년도']).aggregate({'평균기온':'mean'})
df.groupby(['지점명','년도'])['평균기온'].agg(**{'평균기온':'mean'}).reset_index()
# Out:
#       지점명    년도       평균기온
# 0      강릉  1911        NaN
# 1      강릉  1912  11.733333
# 2      강릉  1913  11.683333
# 3      강릉  1914  13.175000
# 4      강릉  1915  12.091667
# ...   ...   ...        ...
# 4844  흑산도  2020  14.100000
# 4845  흑산도  2021  15.258333
# 4846  흑산도  2022  13.983333
# 4847  흑산도  2023  14.308333
# 4848  흑산도  2024  16.677778
#
# [4849 rows x 3 columns]

# %%
df_temp = df.groupby(['지점명','년도'])['평균기온'].agg('mean')
df_temp.plot()

# %% [markdown]
# ### [실습문제] : 지점별 최고기온?

# %%
#df.groupby('지점명')['최고기온'].agg(**{'최고기온':'max'}).reset_index()
#df.groupby('지점명')['최고기온'].agg(**{'최고기온':'max'})

df.groupby('지점명')['최고기온'].agg(**{'최고기온':'max'})
df.groupby('지점명').aggregate({'최고기온':'max'})

# %% [markdown]
# - 인텍스를 초기화 하는 방법

# %%
# 인텍스를 초기화 하는 방법
df.groupby('지점명')['최고기온'].agg(**{'최고기온':'max'}).reset_index()
df.groupby('지점명').aggregate({'최고기온':'max'}).reset_index()

# %% [markdown]
# ### [실습문제] : 지점별 년도별 최다 월합강수량?

# %%
df.groupby(['지점명','년도'])['월합강수량'].agg(**{'최다월합강수량':'max'})
# df.groupby(['지점명','년도']).aggregate({'월합강수량':'max'})
# Out:
#           최다월합강수량
# 지점명 년도
# 강릉  1911     36.5
#     1912    346.1
#     1913    232.5
#     1914    383.4
#     1915    302.3
# ...           ...
# 흑산도 2020    305.2
#     2021    176.0
#     2022    131.4
#     2023    590.5
#     2024    258.3
#
# [4849 rows x 1 columns]

# %% [markdown]
# ### [실습문제]  제주 전역의 지점별+년도별 최고 최고기온, 최저 최저기온 ,최다 월합강수량, 최다 최심적실은?

# %%
df_jeju = df.query(" 지점명 in ('고산','서귀포','성산','성산포','제주') ")
df_jeju = df_jeju.groupby(['지점명','년도']).aggregate({'최고기온':'max',
                                          '최저기온':'min',
                                          '월합강수량':'max',
                                          '최심적설':'max'})

# df_jeju.to_csv('제주-년도별-날씨정보.csv', encoding='cp949')
df_jeju.to_csv('제주-년도별-날씨정보.csv')
df_jeju
# Out:
#           최고기온  최저기온  월합강수량  최심적설
# 지점명 년도
# 고산  1988  30.5  -2.1  207.4   0.5
#     1989  30.5  -1.0  273.2   0.3
#     1990  32.4  -3.5  205.8   2.7
#     1991  31.4  -3.0  368.2   1.0
#     1992  31.7   0.2  326.6   NaN
# ...        ...   ...    ...   ...
# 제주  2020  36.3  -1.4  400.5   2.1
#     2021  34.2  -3.1  493.1   9.2
#     2022  37.5  -0.4  265.8   2.7
#     2023  37.3  -3.4  273.2  12.2
#     2024  35.5  -1.0  271.8   3.7
#
# [294 rows x 4 columns]

# %% [markdown]
# #### 6.가공된 파일 신규 저장하기

# %%
# 가공된 데이터 신규 파일로 저장하기
# df.to_csv('weather_data2.csv', encoding='cp949', mode='w', index=True)
df.to_csv('weather_data2.csv', mode='w', index=True)

# %% [markdown]
# --------------------------

# %% [markdown]
# ## 3. 데이터 시각화하기

# %% [markdown]
# ### [실습] : 지점별 평균기온 그래프

# %%
file
# Out:
# 'OBS_ASOS_MNH_20241013000738.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 한글,그래프크기
plt.rc('font', family='NanumBarunGothic')       # (코랩)한글 폰트
# plt.rc('font', family='Malgun Gothic')          # (win)한글 폰트
plt.rcParams['figure.figsize'] = (10, 4)
plt.rcParams['axes.unicode_minus']

# 1.데이터 불러오기
df = pd.read_csv(file, encoding='CP949')

# 2.컬럼명 지정
df.columns = ['지점', '지점명', '일시', '평균기온', '최고기온', '최저기온',
              '평균현지기압','평균상대습도', '월합강수량', '평균풍',
              '일조시간','최심적설']
df['년도'] = df.일시.str[0:4]
df.head(2)

# 3.지점별 평균 구하기(지점 30개만 추출)
df_ = df.groupby('지점명').aggregate({'평균기온':'mean'}).head(30)

plt.plot(df_, '^', linestyle='solid', c='red', label='평균기온')
plt.xticks(rotation=90)
plt.title('종관관측 지점별 평균기온', fontsize=20)
plt.xlabel('지점명'); plt.ylabel('평균기온');
plt.legend(); plt.grid();
plt.show()

# %% [markdown]
# ### [실습문제] : '제주' 지점의 년도별 평균기온을  선 그래프로 나타내기

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 한글,그래프크기
plt.rc('font', family='NanumBarunGothic')       # (코랩)한글 폰트
# plt.rc('font', family='Malgun Gothic')          # (win)한글 폰트
plt.rcParams['figure.figsize'] = (10, 4)
plt.rcParams['axes.unicode_minus']

# 1.데이터 불러오기
file = 'weather_data2.csv'
df = pd.read_csv(file)
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df


# 2,지점별 연도별 그룹핑하기
df2 = df.query(" 지점명 == '제주' ")
# df2 = df.query(" 지점명 in ('고산','서귀포','성산','성산포','제주') ")
df2 = df2.groupby(['지점명','년도']).aggregate({'평균기온':'mean'}).reset_index()

X = df2.년도
Y = df2.평균기온

# 3.지점별 평균 구하기(지점 30개만 추출)
plt.plot(X, Y, '^', linestyle='solid', c='r', label='평균기온')
plt.title('제주 년도별 평균기온', fontsize=20)
plt.xlabel('년도')
plt.ylabel('평균기온')
plt.xticks(rotation=90)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### [실습]: 제주의 평균기온, 최고기온, 최저기온 통계를 그래프로 나타내기

# %%
# 2. '제주'지점 년도별 기온 데이터 추출하기(년도 30개만)
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['axes.unicode_minus'] = False

data = df.query(" 지점명 == '제주' ")
data1 = data.groupby('년도').평균기온.agg(**{'평균기온':'mean'})
data2 = data.groupby('년도').최고기온.agg(**{'최고기온':'max'})
data3 = data.groupby('년도').최저기온.agg(**{'최저기온':'min'})

# 3. 그래프로 시각화하기
plt.plot(data1, 'o', linestyle='solid', c='r', label='평균기온')
plt.plot(data2, '^', linestyle='solid', c='g', label='최고기온')
plt.plot(data3, 'v', linestyle='solid', c='b', label='최저기온')
plt.title("'제주'지점 년도별 기온 통계", fontsize=15) #제목
plt.xlabel('년도')     # x축 레이블
plt.ylabel('기온')     # y축 레이블
plt.legend()           #범례,기본 위치 : loc='upper left'
plt.xticks(rotation=45)  # x축 레이블 기울이기
plt.grid()               # 격자 표시

plt.show()

# %%
# 2. '제주'지점 년도별 기온 데이터 추출하기(년도 30개만)

data = df.query(" 지점명 == '제주' ")
data1 = data.groupby('년도')['평균기온'].agg(**{'평균기온':'mean'}).reset_index()
data2 = data.groupby('년도')['최고기온'].agg(**{'최고기온':'max'}).reset_index()

# 3. 그래프로 시각화하기
X = data1['년도']
Y1 = data1['평균기온']
Y2 = data2['최고기온']
plt.bar(X, Y1, label='평균기온')
plt.plot(X, Y2, 'o', linestyle='solid', c='r', label='최고기온')
plt.title("'제주'지점 년도별 기온 통계", fontsize=15) #제목
plt.xlabel('년도')        # x축 레이블
plt.ylabel('기온')        # y축 레이블
plt.legend()             #범례,기본 위치 : loc='upper left'
plt.xticks(rotation=45)  # x축 레이블 기울이기

plt.grid()               # 격자 표시

plt.show()

# %% [markdown]
# ### [실습]: 제주의 최고기온(선그래프),평균기온(막대그래프)을 혼합 그래프로 나타내기

# %%
# 3. 그래프로 시각화하기
plt.figure(figsize=(20,5))
plt.title('제주 기온 통계', fontsize=15)         #제목
plt.legend(['최고기온','평균기온']) #범례,기본 위치 : loc='upper left'
plt.xlabel('년도')                 # x축 레이블
plt.ylabel('기온')                 # y축 레이블
plt.xticks(rotation=45)           # x축 레이블 기울이기
plt.grid()                        # 격자 표시

plt.bar(X, Y1)  # 막대 그래프
plt.plot(X, Y2, 'o', linestyle='solid', c='r')  # 선그래프
plt.show()

# %% [markdown]
# ### [실습] : 2중 축 그래프 그리기 :  평균상대습도 & 월합강수량

# %%
# 2.'제주'지점의 평균상대습도 & 일최다강수량 센터수
data = df.groupby(['지점명','년도'])['평균상대습도'].agg(**{'평균상대습도':'mean'}).reset_index()
data = data.query(" 지점명 == '제주' ")
X  = data['년도']
Y1 = data['평균상대습도']

data = df.groupby(['지점명','년도'])['월합강수량'].agg(**{'월합강수량':'mean'}).reset_index()
data = data.query(" 지점명 == '제주' ")
Y2 = data['월합강수량']
# print(Y2)


# 3. 그래프로 시각화하기
plt.rcParams['figure.figsize'] = (10, 5)   # 그래프 크기

fig, ax1 = plt.subplots()
plt.suptitle('평균상대습도 & 월합강수량',fontsize=15)
ax1.plot(X, Y1, color='green')     # 평균상대습도 (왼쪽)
ax1.set_ylabel('평균상대습도', color = 'green', rotation = 90)
ax2 = ax1.twinx()
ax2.plot(X, Y2, color='deeppink')  # 월합강수량 (오른쪽)
ax2.set_ylabel('월합강수량', color = 'deeppink', rotation = 270)

fig.autofmt_xdate(rotation=45)  #X축 레이블 기울이기

plt.savefig('./graph.png')

plt.show()

# %% [markdown]
# -------

# %% [markdown]
# ---------

# %% [markdown]
# 끝!
